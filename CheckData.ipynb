# %%
import pandas as pd

# %%
df = pd.read_csv('test_small.tsv', sep='\t')

# %%
df
# Out:
#       Label                           m_RGUID                m_TagId  \
# 0         0  000099131a074e36acb8b6c173dedd6a         msn-ar-river-2
# 1         0  0000156302f241c6a36ce7a2b762cb8a     edgechrntp-river-2
# 2         1  0000553a00d64720b72a68f337a4626f  edgechrntp-infopane-1
# 3         0  000028333e11482f8e1a20c339ed32b0          ientp-river-1
# 4         0  00000d3376ec4271917e19ea7306fe29     edgechrntp-river-7
# ...     ...                               ...                    ...
# 1995      1  000c8950149f4cb6a8933c29a68976b2    edgechrntp-river-67
# 1996      0  000a1f4aa23b4cf488170d23570a6ef6          video-river-6
# 1997      0  000b3bea710748fca81908f0a6f5cb8d      msnientpInfopane5
# 1998      0  000d325d17db42dbb21b2feb5b0d5bb2     edgechrntp-river-7
# 1999      0  000e014d25744b298994ab730db0e9de            ar-river-10
#
#                 m_EventTime         m_Date m_Market  m_PublisherId  \
# 0     9/23/2021 11:21:45 PM  2021-09-22T00    en-us      250354818
# ...

# %%
df.columns
# Out:
# Index(['Label', 'm_RGUID', 'm_TagId', 'm_EventTime', 'm_Date', 'm_Market',
#        'm_PublisherId', 'm_AdUnitId', 'm_MUID',
#        'PublisherId_ViewRate_Add1ThenLogThenMultiplyBy1000',
#        'DeviceTypeId_ViewRate_Add1ThenLogThenMultiplyBy1000',
#        'DayOfWeek_ViewRate_Add1ThenLogThenMultiplyBy1000',
#        'HourOfDay_ViewRate_Add1ThenLogThenMultiplyBy1000',
#        'Market_ViewRate_Add1ThenLogThenMultiplyBy1000',
#        'MUID_ViewRate_Add1ThenLogThenMultiplyBy1000',
#        'IP4_ViewRate_Add1ThenLogThenMultiplyBy1000',
#        'MUIDXDayOfWeekXHourOfDay_ViewRate_Add1ThenLogThenMultiplyBy1000',
#        'MarketXPublisherIdXTagIdXDeviceTypeId_ViewRate_Add1ThenLogThenMultiplyBy1000',
#        'PublisherIdXTagIdXMUID_ViewRate_Add1ThenLogThenMultiplyBy1000',
#        'PublisherIdXTagIdXIP4_ViewRate_Add1ThenLogThenMultiplyBy1000',
#        'PublisherIdXTagIdXDayOfWeekXHourOfDay_ViewRate_Add1ThenLogThenMultiplyBy1000',
# ...

# %%
npa = df.values

# %%
npa[0]
# Out:
# array([0, '000099131a074e36acb8b6c173dedd6a', 'msn-ar-river-2',
#        '9/23/2021 11:21:45 PM', '2021-09-22T00', 'en-us', 250354818,
#        365314, nan, 196.9150848388672, 344.84033203125, 348.9645690917969,
#        374.17135620117193, 382.8066101074218, 370.4075012207031,
#        353.70855712890625, 375.38821411132807, 273.8836669921875,
#        353.87408447265625, 353.679931640625, 263.5666809082032,
#        279.50946044921875], dtype=object)

# %%
npa[0][10:]
# Out:
# array([344.84033203125, 348.9645690917969, 374.17135620117193,
#        382.8066101074218, 370.4075012207031, 353.70855712890625,
#        375.38821411132807, 273.8836669921875, 353.87408447265625,
#        353.679931640625, 263.5666809082032, 279.50946044921875],
#       dtype=object)

# %%
len(npa[0][10:])
# Out:
# 12

# %%
f = npa[:, 10:].astype(float)

# %%
f.dtype
# Out:
# dtype('float64')
